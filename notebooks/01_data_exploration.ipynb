# %% [markdown]
# ## Step 2: Data Exploration (EDA)

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../data/raw/spam_ham_dataset.csv", encoding="latin-1")

# Check dataset size
print("Dataset shape:", df.shape)

# First 5 rows
display(df.head())

# Column names
print("Columns:", df.columns)

# Missing values
print("Missing values:\n", df.isnull().sum())

# Class distribution (spam / ham)
print("Class distribution:")
print(df['label'].value_counts())

# Numeric label distribution
print("\nNumeric label distribution:")
print(df['label_num'].value_counts())
# Out:
# Dataset shape: (5171, 4)
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
# Columns: Index(['Unnamed: 0', 'label', 'text', 'label_num'], dtype='str')
# Missing values:
#  Unnamed: 0    0
# label         0
# text          0
# label_num     0
# dtype: int64
# Class distribution:
# label
# ham     3672
# spam    1499
# Name: count, dtype: int64
#
# Numeric label distribution:
# label_num
# 0    3672
# 1    1499
# Name: count, dtype: int64
